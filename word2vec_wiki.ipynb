# %% [markdown]
# # Word2Vec Wiki Corpus

# %%
# !git clone https://github.com/ahmadhabib5/word2vec_wiki.git
# Out:
# Cloning into 'word2vec_wiki'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), done.

# %%
# %cd /content/drive/MyDrive/Colab/word2vec_wiki
# Out:
# /content/drive/MyDrive/Colab/word2vec_wiki

# %%
# !wget https://dumps.wikimedia.org/idwiki/latest/idwiki-latest-pages-articles.xml.bz2
# Out:
# --2022-04-20 09:08:12--  https://dumps.wikimedia.org/idwiki/latest/idwiki-latest-pages-articles.xml.bz2
# Resolving dumps.wikimedia.org (dumps.wikimedia.org)... 208.80.154.7, 2620:0:861:1:208:80:154:7
# Connecting to dumps.wikimedia.org (dumps.wikimedia.org)|208.80.154.7|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 761093453 (726M) [application/octet-stream]
# Saving to: ‘idwiki-latest-pages-articles.xml.bz2’
#
# idwiki-latest-pages 100%[===================>] 725.83M  4.13MB/s    in 2m 52s
#
# 2022-04-20 09:11:04 (4.22 MB/s) - ‘idwiki-latest-pages-articles.xml.bz2’ saved [761093453/761093453]

# %%
import gensim
import word2veckeras
gensim.__version__
# Out:
# '3.6.0'

# %%
id_wiki = gensim.corpora.WikiCorpus('idwiki-latest-pages-articles.xml.bz2', lemmatize=False, dictionary={})

# %%
id_wiki.get_texts()
# Out:
# <generator object WikiCorpus.get_texts at 0x7f903dabac50>

# %%
import io
import time
from datetime import timedelta
from tqdm.notebook import tqdm

# %%
start_time = time.time()
article_count = 0
with io.open('idwiki.txt', 'w') as wiki_txt:
    for text in tqdm(id_wiki.get_texts()):

        wiki_txt.write(" ".join(map(str, text)) + '\n')
        article_count += 1

    print('total: {} articles'.format(article_count))

finish_time = time.time()
print('Elapsed time: {}'.format(timedelta(seconds=finish_time-start_time)))
# Out:
# 0it [00:00, ?it/s]
# total: 460575 articles
# Elapsed time: 0:32:38.602149

# %%
import time
import multiprocessing
from datetime import timedelta

from gensim.models import word2vec

start_time = time.time()
print('Training Word2Vec Model...')
sentences = word2vec.LineSentence('idwiki.txt')
id_w2v = word2vec.Word2Vec(sentences, size=300, workers=multiprocessing.cpu_count()-1, iter=5)
id_w2v.save('idwiki_word2vec_300.model')
finish_time = time.time()

print('Finished. Elapsed time: {}'.format(timedelta(seconds=finish_time-start_time)))
# Out:
# Training Word2Vec Model...
# Finished. Elapsed time: 0:46:05.263135

# %%
# !cp -r /content/drive/MyDrive/Colab Notebooks/word2vec_wiki.ipynb /content/drive/MyDrive/Colab/word2vec_wiki
